# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# 1) Load + preprocess MNIST
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Show sample MNIST images
plt.figure(figsize=(6,6))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_train[i], cmap="gray")
    plt.title(f"Label: {y_train[i]}")
    plt.axis("off")
plt.suptitle("Sample MNIST Images")
plt.show()

# Normalize to [0, 1]
X_train = X_train.astype("float32") / 255.0
X_test  = X_test.astype("float32") / 255.0

# Flatten 28x28 -> 784
X_train = X_train.reshape(-1, 784)
X_test  = X_test.reshape(-1, 784)

print("Train shape:", X_train.shape, "Test shape:", X_test.shape)

# 2) Model builder
def build_model(hidden_activation: str, use_dropout: bool = True):
    model = Sequential()

    model.add(Dense(256, activation=hidden_activation, input_shape=(784,)))
    if use_dropout: model.add(Dropout(0.2))

    model.add(Dense(256, activation=hidden_activation))
    if use_dropout: model.add(Dropout(0.2))

    model.add(Dense(128, activation=hidden_activation))
    model.add(Dense(128, activation=hidden_activation))
    model.add(Dense(64, activation=hidden_activation))
    model.add(Dense(32, activation=hidden_activation))

    model.add(Dense(10, activation="softmax"))

    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# -----------------------------
# 3) Train + evaluate helper
# -----------------------------
def train_and_evaluate(hidden_activation: str, epochs: int = 10, batch_size: int = 128):
    print("\n====================================")
    print(f"Training model with hidden activation: {hidden_activation}")
    print("====================================")

    model = build_model(hidden_activation=hidden_activation, use_dropout=True)
    model.summary()

    history = model.fit(
        X_train, y_train,
        validation_split=0.1,
        epochs=epochs,
        batch_size=batch_size,
        verbose=1
    )

    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
    print(f"\nTest Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_acc:.4f}")

    # Predictions
    y_prob = model.predict(X_test, verbose=0)
    y_pred = np.argmax(y_prob, axis=1)

    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    fig, ax = plt.subplots(figsize=(6,6))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(ax=ax)
    plt.title(f"Confusion Matrix - Hidden Activation: {hidden_activation}")
    plt.show()

    # Accuracy Curves
    plt.figure()
    plt.plot(history.history["accuracy"], label="train_acc")
    plt.plot(history.history["val_accuracy"], label="val_acc")
    plt.title(f"Accuracy Curves - {hidden_activation}")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()

    # Loss Curves
    plt.figure()
    plt.plot(history.history["loss"], label="train_loss")
    plt.plot(history.history["val_loss"], label="val_loss")
    plt.title(f"Loss Curves - {hidden_activation}")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

    return {
        "activation": hidden_activation,
        "model": model,
        "history": history,
        "test_loss": test_loss,
        "test_acc": test_acc
    }

# -----------------------------
# 4) Run experiments
# -----------------------------
results_sigmoid = train_and_evaluate("sigmoid", epochs=10)
results_tanh    = train_and_evaluate("tanh", epochs=10)

# -----------------------------
# 5) Summary
# -----------------------------
print("\n================ Summary ================")
print(f"Sigmoid Test Accuracy: {results_sigmoid['test_acc']:.4f}")
print(f"Tanh    Test Accuracy: {results_tanh['test_acc']:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Train shape: (60000, 784) Test shape: (10000, 784)
#
# ====================================
# Training model with hidden activation: sigmoid
# ====================================
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 326,826 (1.25 MB)
#  Trainable params: 326,826 (1.25 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.2829 - loss: 1.9833 - val_accuracy: 0.7518 - val_loss: 0.8344
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.7583 - loss: 0.7778 - val_accuracy: 0.8910 - val_loss: 0.4487
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8883 - loss: 0.4511 - val_accuracy: 0.9450 - val_loss: 0.2519
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9273 - loss: 0.2952 - val_accuracy: 0.9562 - val_loss: 0.1890
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9449 - loss: 0.2244 - val_accuracy: 0.9650 - val_loss: 0.1516
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9511 - loss: 0.1905 - val_accuracy: 0.9667 - val_loss: 0.1303
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9564 - loss: 0.1638 - val_accuracy: 0.9698 - val_loss: 0.1189
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9607 - loss: 0.1432 - val_accuracy: 0.9703 - val_loss: 0.1083
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9670 - loss: 0.1245 - val_accuracy: 0.9753 - val_loss: 0.0918
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9689 - loss: 0.1125 - val_accuracy: 0.9748 - val_loss: 0.0918
#
# Test Loss: 0.1222
# Test Accuracy: 0.9672
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9739    0.9898    0.9818       980
#            1     0.9859    0.9859    0.9859      1135
#            2     0.9629    0.9797    0.9712      1032
#            3     0.9286    0.9782    0.9527      1010
#            4     0.9764    0.9684    0.9724       982
#            5     0.9688    0.9406    0.9545       892
#            6     0.9881    0.9572    0.9724       958
#            7     0.9698    0.9698    0.9698      1028
#            8     0.9556    0.9497    0.9526       974
#            9     0.9637    0.9465    0.9550      1009
#
#     accuracy                         0.9672     10000
#    macro avg     0.9674    0.9666    0.9668     10000
# weighted avg     0.9675    0.9672    0.9672     10000
# ====================================
# Training model with hidden activation: tanh
# ====================================
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 326,826 (1.25 MB)
#  Trainable params: 326,826 (1.25 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8369 - loss: 0.5866 - val_accuracy: 0.9587 - val_loss: 0.1435
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9403 - loss: 0.1994 - val_accuracy: 0.9623 - val_loss: 0.1266
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9550 - loss: 0.1493 - val_accuracy: 0.9680 - val_loss: 0.1081
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9636 - loss: 0.1224 - val_accuracy: 0.9738 - val_loss: 0.0900
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9674 - loss: 0.1082 - val_accuracy: 0.9720 - val_loss: 0.0982
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9740 - loss: 0.0880 - val_accuracy: 0.9757 - val_loss: 0.0868
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9747 - loss: 0.0835 - val_accuracy: 0.9737 - val_loss: 0.0916
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9751 - loss: 0.0796 - val_accuracy: 0.9795 - val_loss: 0.0712
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9780 - loss: 0.0707 - val_accuracy: 0.9757 - val_loss: 0.0823
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9802 - loss: 0.0632 - val_accuracy: 0.9758 - val_loss: 0.0872
#
# Test Loss: 0.0884
# Test Accuracy: 0.9745
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9856    0.9806    0.9831       980
#            1     0.9894    0.9859    0.9876      1135
#            2     0.9768    0.9797    0.9782      1032
#            3     0.9675    0.9723    0.9699      1010
#            4     0.9814    0.9674    0.9744       982
#            5     0.9764    0.9753    0.9759       892
#            6     0.9711    0.9812    0.9761       958
#            7     0.9791    0.9591    0.9690      1028
#            8     0.9504    0.9836    0.9667       974
#            9     0.9661    0.9594    0.9627      1009
#
#     accuracy                         0.9745     10000
#    macro avg     0.9744    0.9744    0.9744     10000
# weighted avg     0.9746    0.9745    0.9745     10000
# ================ Summary ================
# Sigmoid Test Accuracy: 0.9672
# Tanh    Test Accuracy: 0.9745
